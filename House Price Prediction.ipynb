# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report
import copy
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
test_df= pd.read_csv('/content/drive/MyDrive/new ML-DL/boston-housing/test.csv')
test_df_class= pd.read_csv('/content/drive/MyDrive/new ML-DL/boston-housing/submission_example.csv')
train_df= pd.read_csv('/content/drive/MyDrive/new ML-DL/boston-housing/train.csv')

# %%
test_df
# Out:
#       ID     crim    zn  indus  chas  ...  rad  tax  ptratio   black  lstat
# 0      3  0.02729   0.0   7.07     0  ...    2  242     17.8  392.83   4.03
# 1      6  0.02985   0.0   2.18     0  ...    3  222     18.7  394.12   5.21
# 2      8  0.14455  12.5   7.87     0  ...    5  311     15.2  396.90  19.15
# 3      9  0.21124  12.5   7.87     0  ...    5  311     15.2  386.63  29.93
# 4     10  0.17004  12.5   7.87     0  ...    5  311     15.2  386.71  17.10
# ..   ...      ...   ...    ...   ...  ...  ...  ...      ...     ...    ...
# 168  496  0.17899   0.0   9.69     0  ...    6  391     19.2  393.29  17.60
# 169  497  0.28960   0.0   9.69     0  ...    6  391     19.2  396.90  21.14
# 170  499  0.23912   0.0   9.69     0  ...    6  391     19.2  396.90  12.92
# 171  501  0.22438   0.0   9.69     0  ...    6  391     19.2  396.90  14.33
# 172  505  0.10959   0.0  11.93     0  ...    1  273     21.0  393.45   6.48
#
# [173 rows x 14 columns]

# %%
test_df_class
# Out:
#       ID       medv
# 0      3  22.768769
# 1      6  22.768769
# 2      8  22.768769
# 3      9  22.768769
# 4     10  22.768769
# ..   ...        ...
# 168  496  22.768769
# 169  497  22.768769
# 170  499  22.768769
# 171  501  22.768769
# 172  505  22.768769
#
# [173 rows x 2 columns]

# %%
test_df['medv']= test_df_class['medv']

# %%
test_df
# Out:
#       ID     crim    zn  indus  chas  ...  tax  ptratio   black  lstat       medv
# 0      3  0.02729   0.0   7.07     0  ...  242     17.8  392.83   4.03  22.768769
# 1      6  0.02985   0.0   2.18     0  ...  222     18.7  394.12   5.21  22.768769
# 2      8  0.14455  12.5   7.87     0  ...  311     15.2  396.90  19.15  22.768769
# 3      9  0.21124  12.5   7.87     0  ...  311     15.2  386.63  29.93  22.768769
# 4     10  0.17004  12.5   7.87     0  ...  311     15.2  386.71  17.10  22.768769
# ..   ...      ...   ...    ...   ...  ...  ...      ...     ...    ...        ...
# 168  496  0.17899   0.0   9.69     0  ...  391     19.2  393.29  17.60  22.768769
# 169  497  0.28960   0.0   9.69     0  ...  391     19.2  396.90  21.14  22.768769
# 170  499  0.23912   0.0   9.69     0  ...  391     19.2  396.90  12.92  22.768769
# 171  501  0.22438   0.0   9.69     0  ...  391     19.2  396.90  14.33  22.768769
# ...

# %%
train_df
# Out:
#       ID     crim    zn  indus  chas  ...  tax  ptratio   black  lstat  medv
# 0      1  0.00632  18.0   2.31     0  ...  296     15.3  396.90   4.98  24.0
# 1      2  0.02731   0.0   7.07     0  ...  242     17.8  396.90   9.14  21.6
# 2      4  0.03237   0.0   2.18     0  ...  222     18.7  394.63   2.94  33.4
# 3      5  0.06905   0.0   2.18     0  ...  222     18.7  396.90   5.33  36.2
# 4      7  0.08829  12.5   7.87     0  ...  311     15.2  395.60  12.43  22.9
# ..   ...      ...   ...    ...   ...  ...  ...      ...     ...    ...   ...
# 328  500  0.17783   0.0   9.69     0  ...  391     19.2  395.77  15.10  17.5
# 329  502  0.06263   0.0  11.93     0  ...  273     21.0  391.99   9.67  22.4
# 330  503  0.04527   0.0  11.93     0  ...  273     21.0  396.90   9.08  20.6
# 331  504  0.06076   0.0  11.93     0  ...  273     21.0  396.90   5.64  23.9
# 332  506  0.04741   0.0  11.93     0  ...  273     21.0  396.90   7.88  11.9
#
# [333 rows x 15 columns]

# %%
df=pd.concat([train_df,test_df],axis=0).reset_index(drop=True)

# %%
df
# Out:
#       ID     crim    zn  indus  chas  ...  tax  ptratio   black  lstat       medv
# 0      1  0.00632  18.0   2.31     0  ...  296     15.3  396.90   4.98  24.000000
# 1      2  0.02731   0.0   7.07     0  ...  242     17.8  396.90   9.14  21.600000
# 2      4  0.03237   0.0   2.18     0  ...  222     18.7  394.63   2.94  33.400000
# 3      5  0.06905   0.0   2.18     0  ...  222     18.7  396.90   5.33  36.200000
# 4      7  0.08829  12.5   7.87     0  ...  311     15.2  395.60  12.43  22.900000
# ..   ...      ...   ...    ...   ...  ...  ...      ...     ...    ...        ...
# 501  496  0.17899   0.0   9.69     0  ...  391     19.2  393.29  17.60  22.768769
# 502  497  0.28960   0.0   9.69     0  ...  391     19.2  396.90  21.14  22.768769
# 503  499  0.23912   0.0   9.69     0  ...  391     19.2  396.90  12.92  22.768769
# 504  501  0.22438   0.0   9.69     0  ...  391     19.2  396.90  14.33  22.768769
# ...

# %%
df.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
train,valid,test= np.split(df.sample(frac=1),[int(0.6*len(df)),int(0.8*len(df))])
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
def standard_scaler(dataframe, y_label, x_labels=None):
    dataframe = copy.deepcopy(dataframe)

    if x_labels is None:
        X = dataframe[[c for c in dataframe.columns if c != y_label]].values
    else:
        if len(x_labels) == 1:
            X = dataframe[x_labels[0]].values.reshape(-1, 1)
        else:
            X = dataframe[x_labels].values

    Y = dataframe[y_label].values.reshape(-1, 1)
    data = np.hstack((X, Y))
    return data, X, Y

# %%
x_labels = [col for col in df.columns if col != 'medv']
train, x_train,y_train= standard_scaler(train,'medv',x_labels=x_labels)
valid, x_valid,y_valid= standard_scaler(valid,'medv',x_labels=x_labels)
test,x_test,y_test=standard_scaler(test,'medv',x_labels=x_labels)

# %%
lr_model= LinearRegression()
lr_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict_y= lr_model.predict(x_test)

# %%
predict_y
# Out:
# array([[19.03163643],
#        [23.38582498],
#        [18.94452512],
#        [21.0607084 ],
#        [22.05735075],
#        [17.60732428],
#        [17.1256584 ],
#        [21.59135741],
#        [22.3293736 ],
#        [24.10367577],
#        [20.49596083],
#        [31.52875947],
#        [24.15108541],
#        [28.11865165],
#        [29.50149875],
#        [22.95677439],
#        [15.08319735],
#        [23.58601291],
#        [28.80406684],
#        [25.35686857],
#        [26.53893836],
#        [22.1621544 ],
#        [15.49741714],
#        [23.80826408],
#        [18.98622138],
#        [29.82165805],
#        [25.61963826],
#        [24.17583753],
#        [23.55790534],
#        [28.71859355],
#        [30.05934074],
#        [21.01159592],
#        [28.17737472],
#        [26.52357362],
#        [17.35465348],
#        [18.92915262],
#        [27.77768033],
#        [30.98423908],
#        [20.50574654],
#        [20.45090247],
#        [19.70086924],
# ...

# %%
error = abs(predict_y[1] - y_test[1])
print(f'Actual amount: ${y_test[1]*1000}')
print(f'Prediction amount: ${predict_y[1]*1000}')
print(f"Absolute error: {error[0]}")
print(f'Actual predicted price: ${(predict_y[1]*1000)-(error[0]*1000)}')
# Out:
# Actual amount: $[22768.76876877]
# Prediction amount: $[23385.82497719]
# Absolute error: 0.6170562084209976
# Actual predicted price: $[22768.76876877]

# %% [markdown]
# this model is off $620

# %% [markdown]
# # Model Eveluation

# %%
mean_absolute= mean_absolute_error(y_test,predict_y)
mean_square= mean_squared_error(y_test,predict_y)
r_2= r2_score(y_test,predict_y)


print('Mean Absolute Error\n',mean_absolute )
print('Mean Square Error\n',mean_square )
print('R2 Score \n',r_2 )
# Out:
# Mean Absolute Error
#  3.8264227967449624
# Mean Square Error
#  28.75826845962298
# R2 Score
#  0.5451286100157507
